# %% [markdown]
# # Pandas file handling

# %%
import pandas as pd
df = pd.read_csv('pokemon_data.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
print(df.head(10))
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#read a specific location with iloc
print(df.iloc[0])
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object

# %%
#read a specific value based on a filter the loc keyword
print(df.loc[df["Type 2"] == "Dragon"])
# Out:
#        #                       Name    Type 1  Type 2   HP  Attack  Defense  \
# 7      6  CharizardMega Charizard X      Fire  Dragon   78     130      111
# 196  181      AmpharosMega Ampharos  Electric  Dragon   90      95      105
# 249  230                    Kingdra     Water  Dragon   75      95       95
# 275  254      SceptileMega Sceptile     Grass  Dragon   70     110       75
# 360  329                    Vibrava    Ground  Dragon   50      70       50
# 361  330                     Flygon    Ground  Dragon   80     100       80
# 540  483                     Dialga     Steel  Dragon  100     120      120
# 541  484                     Palkia     Water  Dragon   90     120      100
# 544  487      GiratinaAltered Forme     Ghost  Dragon  150     100      120
# 545  487       GiratinaOrigin Forme     Ghost  Dragon  150     120      100
# 694  633                      Deino      Dark  Dragon   52      65       50
# ...

# %% [markdown]
# ## Sorting and describing data

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values(["Name", "Type 1"], ascending = [False, True])
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ## Making chnages to the data

# %%
df["Totals"] = df["Attack"] + df["Defense"]
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Totals
# 0       65     45           1      False      98
# 1       80     60           1      False     125
# 2      100     80           1      False     165
# 3      120     80           1      False     223
# 4       50     65           1      False      95

# %%
#Deleting a column
df = df.drop(columns = ["Totals"])
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df["Totals"] = df.iloc[:, 4:10].sum(axis = 1)
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Totals
# 0       65     45           1      False     318
# 1       80     60           1      False     405
# 2      100     80           1      False     525
# 3      120     80           1      False     625
# 4       50     65           1      False     309

# %% [markdown]
# ## Saving the file after modification

# %%
#df.to_csv("modified.csv", index = False)
#df.to_excel("modified.xlsx", index = False)
df.to_csv("modified.txt", index = False, sep = " ")

# %% [markdown]
# ## Data filtering

# %%
#df.loc[(df["Type 1"] == "Grass") & (df["Type 2"] == "Poison") & (df["Speed"] < 40)].to_csv("filterd_data.csv", index = False)
#df.loc[(df["Type 1"] == "Grass") | (df["Type 2"] == "Poison

#We can also use regular expresions 
#flags = re.I is for ignoring case sensitivity
import re
df.loc[df["Name"].str.contains('der|Aur', flags = re.I, regex = True)]
# Out:
#        #                   Name  Type 1  Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur   Grass  Poison   45      49       49
# 1      2                Ivysaur   Grass  Poison   60      62       63
# 2      3               Venusaur   Grass  Poison   80      82       83
# 3      3  VenusaurMega Venusaur   Grass  Poison   80     100      123
# 4      4             Charmander    Fire     NaN   39      52       43
# 97    90               Shellder   Water     NaN   30      65      100
# 138  128                 Tauros  Normal     NaN   75     100       95
# 730  662            Fletchinder    Fire  Flying   62      73       55
# 768  698                 Amaura    Rock     Ice   77      59       50
# 769  699                Aurorus    Rock     Ice  123      77       72
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Totals
# 0         65       65     45           1      False     318
# 1         80       80     60           1      False     405
# ...

# %% [markdown]
# ## Filter with conditions

# %%
#~ means 'not'
df.loc[~df["Name"].str.contains("aur")]
# Out:
#        #                       Name   Type 1  Type 2  HP  Attack  Defense  \
# 4      4                 Charmander     Fire     NaN  39      52       43
# 5      5                 Charmeleon     Fire     NaN  58      64       58
# 6      6                  Charizard     Fire  Flying  78      84       78
# 7      6  CharizardMega Charizard X     Fire  Dragon  78     130      111
# 8      6  CharizardMega Charizard Y     Fire  Flying  78     104       78
# ..   ...                        ...      ...     ...  ..     ...      ...
# 795  719                    Diancie     Rock   Fairy  50     100      150
# 796  719        DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720        HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720         HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721                  Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Totals
# ...

# %% [markdown]
# ## Changing data on condition

# %%
#df.loc[df["Type 1"] == "Grass", "Type 1"] = "Not Grass"
#We can change multiple colum at the same time
df.loc[df["Type 1"] == "Not Grass", ["Generation", "Legendary"]] = [0, True]
df
# Out:
#        #                   Name     Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur  Not Grass  Poison  45      49       49
# 1      2                Ivysaur  Not Grass  Poison  60      62       63
# 2      3               Venusaur  Not Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur  Not Grass  Poison  80     100      123
# 4      4             Charmander       Fire     NaN  39      52       43
# ..   ...                    ...        ...     ...  ..     ...      ...
# 795  719                Diancie       Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie       Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined    Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound    Psychic    Dark  80     160       60
# 799  721              Volcanion       Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Totals
# ...

# %% [markdown]
# ## Aggregate Statistics with (GroupBy) function

# %%
#df.groupby(["Type 1"]).mean().sort_values("Defense", ascending = False)
df.groupby(["Type 1"]).count().sort_values("Defense", ascending = False)
# Out:
#              #  Name  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Water      112   112      53  112     112      112      112      112    112
# Normal      98    98      37   98      98       98       98       98     98
# Not Grass   70    70      37   70      70       70       70       70     70
# Bug         69    69      52   69      69       69       69       69     69
# Psychic     57    57      19   57      57       57       57       57     57
# Fire        52    52      24   52      52       52       52       52     52
# Electric    44    44      17   44      44       44       44       44     44
# Rock        44    44      35   44      44       44       44       44     44
# Ghost       32    32      22   32      32       32       32       32     32
# Dragon      32    32      21   32      32       32       32       32     32
# Ground      32    32      19   32      32       32       32       32     32
# ...
